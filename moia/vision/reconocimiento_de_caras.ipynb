# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/drive/1d8lmQCL40i0rGj_qMFjj5dUXdQYR_ixe" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ---
#
# # **Licencia**
#
# **Autor**: Juan Francisco Puentes Calvo
#
# **Licencia**: GPL v3 (https://www.gnu.org/licenses/gpl-3.0.html)

# %% [markdown]
# # **Reconocimientos**
#
# * Ninguno, por ahora.
#
# ---

# %% [markdown]
# ## Reconocimiento de caras

# %%
urls=[
      "https://media.vogue.mx/photos/5cfe891727998c247198c76d/2:3/w_2560%2Cc_limit/GettyImages-1153799667.jpg",
      "https://images.ecestaticos.com/G8wdPYdInsxwj0lphX-c3fufnBM=/0x0:1600x900/1200x1200/filters:fill(white):format(jpg)/f.elconfidencial.com%2Foriginal%2Fadb%2F6a7%2F61d%2Fadb6a761d98cd48693a79ea75b2db8c6.jpg",
      "https://hips.hearstapps.com/hmg-prod/images/jennifer-lawrence-attends-the-anatomie-dune-chute-red-news-photo-1704650471.jpg?crop=1.00xw:0.668xh;0,0.0887xh&resize=640:*",
      "https://aws-modapedia.vogue.es/prod/designs/v1/assets/640x1179/1783.jpg",
      "https://media.revistavanityfair.es/photos/60e850f3a9295aeb634d0a78/master/w_1600%2Cc_limit/14289.jpg",
      "https://s3.abcstatics.com/media/estilo/2021/12/07/apertura-lawrence-ksoC--1248x698@abc.jpg",
      "https://media.revistavanityfair.es/photos/60e8406c70839211f5444c64/master/w_1600%2Cc_limit/151864.jpg",
      "https://e00-telva.uecdn.es/imagenes/2015/11/27/celebrities/1448615201_extras_noticia_head_moviles_1.jpg",
      "https://m.media-amazon.com/images/M/MV5BOTU3NDE5MDQ4MV5BMl5BanBnXkFtZTgwMzE5ODQ3MDI@._V1_.jpg",
      "https://www.hola.com/horizon/landscape/460ea095764e-jennifer-lawrence.jpg",
      "https://cdn.hobbyconsolas.com/sites/navi.axelspringer.es/public/media/image/2024/04/jennifer-lawrence-3298462.jpg?tf=3840x"
     ]
try:
    import google.colab
    # !pip -q install mediapipe opencv-python-headless pillow requests
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
import cv2
import mediapipe as mp
import numpy as np
from PIL import Image
from helpers import read_image

# Inicializa FaceLandmarker
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

# Función para descargar una imagen desde una URL
def download_image(url, max_width=500):
    img = read_image(url)
    if img is not None:
        img = img.convert('RGB')

        # Redimensionar la imagen si es necesario
        if img.width > max_width:
            ratio = max_width / float(img.width)
            height = int((float(img.height) * float(ratio)))
            img = img.resize((max_width, height), Image.LANCZOS)

        return np.array(img)
    else:
        return None

# Procesa cada URL
for url in urls:
    # Descarga la imagen
    image_np = download_image(url)

    if image_np is None: continue;

    # Convertir imagen a formato de OpenCV
    image_cv = cv2.cvtColor(image_np, cv2.COLOR_RGB2BGR)

    print(url)

    # Detectar caras en la imagen
    with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
        results = face_detection.process(image_cv)

        if results.detections:
            # Extraer la cara con mayor probabilidad (primer resultado)
            detection = results.detections[0]
            print(f"Cara detectada con probabilidad: {detection.score[0]}")

            # Dibujar detección en la imagen
            mp_drawing.draw_detection(image_cv, detection)

            # Extraer coordenadas de la caja de la cara
            bboxC = detection.location_data.relative_bounding_box
            ih, iw, _ = image_cv.shape
            x1, y1 = int(bboxC.xmin * iw), int(bboxC.ymin * ih)
            x2, y2 = x1 + int(bboxC.width * iw), y1 + int(bboxC.height * ih)
            face_image = image_cv[y1:y2, x1:x2]

            # Convertir la imagen de la cara extraída a RGB
            face_image_rgb = cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB)

            # Calcular los puntos de referencia faciales usando FaceMesh
            with mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True) as face_mesh:
                face_results = face_mesh.process(face_image_rgb)

                if face_results.multi_face_landmarks:
                    for face_landmarks in face_results.multi_face_landmarks:
                        mp_drawing.draw_landmarks(
                            image=face_image_rgb,
                            landmark_list=face_landmarks,
                            connections=mp_face_mesh.FACEMESH_TESSELATION,
                            landmark_drawing_spec=None,
                            connection_drawing_spec=mp_drawing.DrawingSpec(color=(0,255,0), thickness=1, circle_radius=1)
                        )

                    # Mostrar imagen de la cara con puntos de referencia dibujados
                    final_image = Image.fromarray(face_image_rgb)
                    display(final_image)
        else:
          print("\t","No hay caras")
# Out:
# https://media.vogue.mx/photos/5cfe891727998c247198c76d/2:3/w_2560%2Cc_limit/GettyImages-1153799667.jpg
# Cara detectada con probabilidad: 0.8475229144096375
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768154192.761290   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154192.764025   26311 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1768154192.788228   26304 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154192.802688   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154192.804817   26322 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154192.809832   26318 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154192.828039   26317 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154192.831832   26316 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# <PIL.Image.Image image mode=RGB size=339x339>
# https://images.ecestaticos.com/G8wdPYdInsxwj0lphX-c3fufnBM=/0x0:1600x900/1200x1200/filters:fill(white):format(jpg)/f.elconfidencial.com%2Foriginal%2Fadb%2F6a7%2F61d%2Fadb6a761d98cd48693a79ea75b2db8c6.jpg
# Cara detectada con probabilidad: 0.9013363122940063
# I0000 00:00:1768154193.082010   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.086623   26332 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.109400   26324 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154193.122126   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.123898   26343 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.128715   26340 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154193.146844   26333 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=222x222>
# https://hips.hearstapps.com/hmg-prod/images/jennifer-lawrence-attends-the-anatomie-dune-chute-red-news-photo-1704650471.jpg?crop=1.00xw:0.668xh;0,0.0887xh&resize=640:*
# Cara detectada con probabilidad: 0.8622948527336121
# I0000 00:00:1768154193.320842   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.323167   26354 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.347745   26348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154193.361816   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.363775   26365 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.369227   26359 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154193.388806   26356 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=168x168>
# https://aws-modapedia.vogue.es/prod/designs/v1/assets/640x1179/1783.jpg
# Cara detectada con probabilidad: 0.8926213383674622
# I0000 00:00:1768154193.618965   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.620852   26376 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.642555   26368 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154193.656101   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.658476   26387 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.660817   26380 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154193.684277   26378 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=240x240>
# https://media.revistavanityfair.es/photos/60e850f3a9295aeb634d0a78/master/w_1600%2Cc_limit/14289.jpg
# Cara detectada con probabilidad: 0.9010225534439087
# I0000 00:00:1768154193.907179   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.908941   26397 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.927934   26389 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154193.938674   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154193.940355   26408 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154193.942297   26401 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154193.959846   26400 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=109x109>
# https://s3.abcstatics.com/media/estilo/2021/12/07/apertura-lawrence-ksoC--1248x698@abc.jpg
# Cara detectada con probabilidad: 0.9008545279502869
# I0000 00:00:1768154194.229125   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154194.231191   26418 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154194.246328   26410 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154194.260174   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154194.262141   26429 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154194.264445   26419 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154194.278755   26423 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=131x131>
# https://media.revistavanityfair.es/photos/60e8406c70839211f5444c64/master/w_1600%2Cc_limit/151864.jpg
# Cara detectada con probabilidad: 0.8474114537239075
# I0000 00:00:1768154194.454885   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154194.456672   26439 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154194.470857   26433 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154194.483848   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154194.485734   26450 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154194.487723   26443 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154194.499146   26442 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=91x91>
# https://e00-telva.uecdn.es/imagenes/2015/11/27/celebrities/1448615201_extras_noticia_head_moviles_1.jpg
# Cara detectada con probabilidad: 0.885970950126648
# I0000 00:00:1768154194.927454   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154194.929206   26466 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154194.943463   26460 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154194.955356   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154194.957388   26477 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154194.959631   26471 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154194.978336   26470 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=216x216>
# https://m.media-amazon.com/images/M/MV5BOTU3NDE5MDQ4MV5BMl5BanBnXkFtZTgwMzE5ODQ3MDI@._V1_.jpg
# Cara detectada con probabilidad: 0.8819714784622192
# I0000 00:00:1768154195.253039   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154195.254962   26488 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154195.268238   26480 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154195.279241   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154195.281029   26499 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154195.284683   26491 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154195.301024   26489 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=233x233>
# https://www.hola.com/horizon/landscape/460ea095764e-jennifer-lawrence.jpg
# Cara detectada con probabilidad: 0.805316150188446
# I0000 00:00:1768154195.534405   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154195.536238   26509 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154195.549494   26501 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154195.560818   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154195.562530   26520 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154195.564490   26511 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154195.574377   26510 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=162x162>
# https://cdn.hobbyconsolas.com/sites/navi.axelspringer.es/public/media/image/2024/04/jennifer-lawrence-3298462.jpg?tf=3840x
# Cara detectada con probabilidad: 0.7056527733802795
# I0000 00:00:1768154195.956147   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154195.957910   26530 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154195.969459   26522 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1768154195.979624   25875 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768154195.981204   26541 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.1), renderer: Mesa Intel(R) UHD Graphics 620 (KBL GT2)
# W0000 00:00:1768154195.982967   26533 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768154195.990566   26531 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <PIL.Image.Image image mode=RGB size=120x120>

# %%
if IN_COLAB:
    # Instalar las dependencias necesarias
    # !pip -q install opencv-python-headless
    # !pip -q install dlib
    # !pip -q install face_recognition

import cv2
import dlib
import face_recognition
import urllib.request
import numpy as np
from matplotlib import pyplot as plt
from helpers import read_image_with_flags

# Descargar imágenes desde URLs y preparar el dataset
def prepare_training_images(urls):
    training_images = []
    for url in urls:
        image = read_image_with_flags(url, cv2.IMREAD_COLOR)
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        training_images.append(rgb_image)
    return training_images

training_images = prepare_training_images(urls)

# Codificar el rostro en las imágenes de entrenamiento
known_face_encodings = []

for image in training_images:
    face_encodings = face_recognition.face_encodings(image)
    if face_encodings:
        known_face_encodings.append(face_encodings[0])

# Promediar las codificaciones faciales
if known_face_encodings:
    person_face_encoding = np.mean(known_face_encodings, axis=0)
else:
    raise ValueError("No se encontraron rostros en las imágenes de entrenamiento")

# Reconocer el rostro entrenado en una nueva imagen con múltiples personas
def recognize_faces_in_image(image_url, known_face_encoding, person_name="Jennifer"):
    image_to_recognize = read_image_with_flags(image_url, cv2.IMREAD_UNCHANGED)
    rgb_image_to_recognize = cv2.cvtColor(image_to_recognize, cv2.COLOR_BGR2RGB)

    face_locations = face_recognition.face_locations(rgb_image_to_recognize)
    face_encodings = face_recognition.face_encodings(rgb_image_to_recognize, face_locations)

    plt.axis("off")
    plt.imshow(rgb_image_to_recognize)
    plt.show()

    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        match = face_recognition.compare_faces([known_face_encoding], face_encoding)
        name = "Desconocido"

        if match[0]:
            name = person_name
            cv2.rectangle(rgb_image_to_recognize, (left, top), (right, bottom), (0, 255, 0), 2)
            cv2.putText(rgb_image_to_recognize, name, (left + 6, bottom - 6), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

    plt.axis("off")
    plt.imshow(rgb_image_to_recognize)
    plt.show()

# URL de la imagen con múltiples personas
test_image_url = "https://img.buzzfeed.com/buzzfeed-static/static/2018-03/1/15/asset/buzzfeed-prod-fastlane-02/sub-buzz-31755-1519935310-2.jpg?downsize=1600"
recognize_faces_in_image(test_image_url, person_face_encoding, person_name="Jennifer")
